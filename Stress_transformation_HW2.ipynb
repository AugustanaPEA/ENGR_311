# %% [markdown]
# ## Stress Transformation
#
# As mentioned in the lecture, stress transformation is not something that is generally done by hand.  So this assigment asks you to build a little code that takes an initial expression for a state of stress, and produces a transformed expression of that same state. <br><br>
#
# Your inputs should be the initial values for the normal stresses in the x and y direction, the shear stress, and the rotation.  Be sure to follow sign convention:
# * Compressive stresses are negative, while tensile stresses are positive
# * Shear is positive if it is CCW on x-side of the element
# * Rotation is positive if it is CCW
#
# Here's a little help getting started.  The first cell gives you a structure for the function you'll create.   The second runs the function and prints the output.   If you aren't familiar with using Python to do calculation

# %%
import numpy as np

def transform(sx,sy,tau,rot):
    # Calculate your transformed values
    # Remmeber that numpy functions like np.sin() (and python math functions) assume
    # that angle values are in radians





    # Return your transformed values
    return sxt, syt, taut

# %%
# Units must all be the same (MPa, GPa, ksi, etc...)
# Rotation is in degrees
sx = 45
sy = -60
tau = 30
rot = -10   # in degrees

# Run your function
sxt, syt, taut = transform(sx,sy,tau,rot)

# Print out the transformed values
print("sigma_x = ", round(sxt,2))
print("sigma_y = ", round(syt,2))
print(" shear = ", round(taut,2))
