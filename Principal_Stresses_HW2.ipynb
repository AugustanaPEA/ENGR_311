# %% [markdown]
# ## Principal Stresses
#
# Enter the initial values for the normal stresses in the x and y direction and the shear stress.  Be sure to follow sign convention:
#
# * Compressive stresses are negative, while tensile stresses are positive
# * Shear is positive if it is CCW on x-side of the element
# * Rotation is positive if it is CCW
#
# Here's a little help getting started. The first cell gives you a structure for the function you'll create. <br><br>
#
# The second runs the function and prints the output: the principal stresses, the principal planes, the maximum shear stress, the planes of maximum shear stress, and the average normal stress.

# %%
import numpy as np

def principal(sx,sy,tau):
    # Calculate your transformed values
    # Remmeber that numpy functions (and python math functions) assume
    # that angle values are in radians





    # Return your transformed values
    # Notice that the maximum shear planes are not calculated above:
    # they are always 45 degrees away from the two principal planes
    # See the cell below if you are not sure what the variables stand for
    return sp1, sp2, th1, th2, mip, th1 + 45.0, th2 + 45.0, ave

# %%
# Units must all be the same (MPa, GPa, etc...)
# Rotation is in degrees
sx = 45.0
sy = -60
tau = 30

# Run your function
sp1, sp2, th1, th2, mip, mip1, mip2, ave = principal(sx,sy,tau)

# Print out the results
print("Principal Stresses: ", round(sp1,2), round(sp2,2))
print("Principal Planes (degrees): ", round(th1,2), round(th2,2))
print("Max In-plane Shear: ", round(mip,2))
print("Shear planes: ", round(mip1,2), round(mip2,2))
print("Average normal stress: ", ave)
